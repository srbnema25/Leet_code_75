# %% [markdown]
# # 3. Longest Substring Without Repeating Characters

# %% [markdown]
# Given a string s, find the length of the longest substring without duplicate characters.
#
#
#
# Example 1:
#
# Input: s = "abcabcbb"
# Output: 3
# Explanation: The answer is "abc", with the length of 3. Note that "bca" and "cab" are also correct answers.
#
# Example 2:
#
# Input: s = "bbbbb"
# Output: 1
# Explanation: The answer is "b", with the length of 1.
#
# Example 3:
#
# Input: s = "pwwkew"
# Output: 3
# Explanation: The answer is "wke", with the length of 3.
# Notice that the answer must be a substring, "pwke" is a subsequence and not a substring.
#
#
# Constraints:
#
# 0 <= s.length <= 5 * 104
# s consists of English letters, digits, symbols and spaces.

# %% [markdown]
# # Time complexity = O(N3)

# %%
def lengthOfLongestSubstring(s):
    longest_len = 0
    longest = ''
    for i in range(len(s)):
        for q in range(i+1, len(s)+1):
            if len(s[i:q])==len(set(s[i:q])):
                longest_len = max(longest_len, len(s[i:q]))
        
    return longest_len

# %%
lengthOfLongestSubstring("abcabcbb")
# Out:
# 3

# %%
lengthOfLongestSubstring("bbbbb")
# Out:
# 1

# %%
lengthOfLongestSubstring("pwwkew")
# Out:
# 3

# %% [markdown]
# # Use Sliding Window

# %%
# My solution

# %%
def lengthOfLongestSubstring(s):
    longest_len = 0
    longest = ''
    
    for lp in range(0, len(s)+1):
        rp = lp + 1
        
        while (len(s[lp:rp])==len(set(s[lp:rp]))) & (rp <= len(s)):
            if len(s[lp:rp]) > longest_len:
                longest_len = len(s[lp:rp])
                longest = s[lp:rp]
            rp += 1
        
    return longest_len

# %%
lengthOfLongestSubstring("abcabcbb")
# Out:
# 3

# %%
lengthOfLongestSubstring("bbbbb")
# Out:
# 1

# %%
lengthOfLongestSubstring("pwwkew")
# Out:
# 3

# %%
# Neet code solution

# %%
def lengthOfLongestSubstring(s):
    charSet = set()
    l = 0
    res = 0
    
    for r in range(len(s)):
        while s[r] in charSet:
            charSet.remove(s[l])
            l += 1
            
        charSet.add(s[r])
        
        res = max(res, r-l+1)
        
    return res

# %%
lengthOfLongestSubstring("abcabcbb")
# Out:
# 3

# %%
lengthOfLongestSubstring("bbbbb")
# Out:
# 1

# %%
lengthOfLongestSubstring("pwwkew")
# Out:
# 3
